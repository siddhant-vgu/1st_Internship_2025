# %%
print("hellow world")
# Out:
# hellow world

# %%
A=12
B="Siddhant"
C = True
D = int(C)
print(type(A))
print(type(B))
print(type(C))
print(type(D))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %%
Name = input("Enter your name:")
print(Name)

# %%
a=3
b=5
c=a+b
d=a-b
print(c)
print(d)
print(a**b)
print(a*b)
# Out:
# 8
# -2
# 243
# 15

# %% [markdown]
# Comparison operator

# %%
a=3
b=5
print(a>b)
print(a==b)
print(a<b)
print(a!=b)
# Out:
# False
# False
# True
# True

# %% [markdown]
# Logical operator

# %%
Age = 18
print(Age >19 and Age <20)
# Out:
# False

# %% [markdown]
# Assignment operator

# %%
X=3
print(X)

X -= 3
print(X)
# Out:
# 3
# 0

# %% [markdown]
# Identity operator

# %%
A=3
B=A
print(A is B)
# Out:
# True
